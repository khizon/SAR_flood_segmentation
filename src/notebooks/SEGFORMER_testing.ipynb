# %%
from skimage.io import imread, imshow
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import torch
from torch.utils.data import Dataset, DataLoader
from sen1floods11_dataset import Sen1Floods11Dataset, Sen1Floods11DataModule

import os
ROOT = os.path.dirname(os.getcwd())
hand_labeled_data = os.path.join(ROOT, 'sen1floods11', 'hand_labeled.csv')
weak_labeled_data = os.path.join(ROOT, 'sen1floods11', 'weak_labeled.csv')
ROOT
# Out:
# '/home/genrev_kiel_hizon/SAR_flood_segmentation'

# %%
def sample_img(dataset, idx=None):
    if not idx:
        idx = np.random.randint(len(dataset))
        
    _, ax = plt.subplots(1,3)
    
    ax[0].imshow(dataset['img'][idx][0])
    ax[1].imshow(dataset['img'][idx][1])
    ax[2].imshow(dataset['label'][idx])
    
    for a in ax:
        a.set_xticks([])
        a.set_yticks([])
        
    plt.show()
    
    return None

# %%
hand_labeled = Sen1Floods11DataModule(hand_labeled_data, 'HandLabeled', 8, debug=True, transforms=True)
hand_labeled.prepare_data()
train = hand_labeled.train_dataloader()
sample_img(next(iter(train)))

# %%
import torchvision.transforms.functional as F
raw_image = next(iter(train))['img'][0]
for c in range(3):
    min_c = raw_image[c].min()
    max_c = raw_image[c].max()
    new_image = (raw_image[c]-min_c)/(max_c-min_c)
pil_image = F.to_pil_image(new_image)

# %%
from transformers import pipeline
generator = pipeline(model="facebook/sam-vit-base", task="mask-generation")
outputs = generator(pil_image)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 from transformers import pipeline
#       2 generator = pipeline(model="facebook/sam-vit-base", task="mask-generation")
# ----> 3 outputs = generator(pil_image)
#
# File ~/sar_env_2/lib/python3.9/site-packages/transformers/pipelines/mask_generation.py:168, in MaskGenerationPipeline.__call__(self, image, num_workers, batch_size, *args, **kwargs)
#     133 def __call__(self, image, *args, num_workers=None, batch_size=None, **kwargs):
#     134     """
#     135     Generates binary segmentation masks
#     136
#    (...)
#     166
#     167     """
# --> 168     return super().__call__(image, *args, num_workers=num_workers, batch_size=batch_size, **kwargs)
#
# File ~/sar_env_2/lib/python3.9/site-packages/transformers/pipelines/base.py:1112, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1110     return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1111 elif self.framework == "pt" and isinstance(self, ChunkPipeline):
# -> 1112     return next(
#    1113         iter(
#    1114             self.get_iterator(
#    1115                 [inputs], num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1116             )
#    1117         )
#    1118     )
#    1119 else:
#    1120     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/sar_env_2/lib/python3.9/site-packages/transformers/pipelines/pt_utils.py:124, in PipelineIterator.__next__(self)
#     121     return self.loader_batch_item()
#     123 # We're out of items within a batch
# --> 124 item = next(self.iterator)
#     125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#
# File ~/sar_env_2/lib/python3.9/site-packages/transformers/pipelines/pt_utils.py:266, in PipelinePackIterator.__next__(self)
#     263             return accumulator
#     265 while not is_last:
# --> 266     processed = self.infer(next(self.iterator), **self.params)
#     267     if self.loader_batch_size is not None:
#     268         if isinstance(processed, torch.Tensor):
#
# File ~/sar_env_2/lib/python3.9/site-packages/transformers/pipelines/base.py:1026, in Pipeline.forward(self, model_inputs, **forward_params)
#    1024     with inference_context():
#    1025         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1026         model_outputs = self._forward(model_inputs, **forward_params)
#    1027         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1028 else:
#
# File ~/sar_env_2/lib/python3.9/site-packages/transformers/pipelines/mask_generation.py:236, in MaskGenerationPipeline._forward(self, model_inputs, pred_iou_thresh, stability_score_thresh, mask_threshold, stability_score_offset)
#     232 masks = self.image_processor.post_process_masks(
#     233     low_resolution_masks, original_sizes, reshaped_input_sizes, mask_threshold, binarize=False
#     234 )
#     235 iou_scores = model_outputs["iou_scores"]
# --> 236 masks, iou_scores, boxes = self.image_processor.filter_masks(
#     237     masks[0],
#     238     iou_scores[0],
#     239     original_sizes[0],
#     240     input_boxes[0],
#     241     pred_iou_thresh,
#     242     stability_score_thresh,
#     243     mask_threshold,
#     244     stability_score_offset,
#     245 )
#     246 return {
#     247     "masks": masks,
#     248     "is_last": is_last,
#     249     "boxes": boxes,
#     250     "iou_scores": iou_scores,
#     251 }
#
# File ~/sar_env_2/lib/python3.9/site-packages/transformers/models/sam/image_processing_sam.py:654, in SamImageProcessor.filter_masks(self, masks, iou_scores, original_size, cropped_box_image, pred_iou_thresh, stability_score_thresh, mask_threshold, stability_score_offset, return_tensors)
#     627 """
#     628 Filters the predicted masks by selecting only the ones that meets several criteria. The first criterion being
#     629 that the iou scores needs to be greater than `pred_iou_thresh`. The second criterion is that the stability
#    (...)
#     651         If `pt`, returns `torch.Tensor`. If `tf`, returns `tf.Tensor`.
#     652 """
#     653 if return_tensors == "pt":
# --> 654     return self._filter_masks_pt(
#     655         masks=masks,
#     656         iou_scores=iou_scores,
#     657         original_size=original_size,
#     658         cropped_box_image=cropped_box_image,
#     659         pred_iou_thresh=pred_iou_thresh,
#     660         stability_score_thresh=stability_score_thresh,
#     661         mask_threshold=mask_threshold,
#     662         stability_score_offset=stability_score_offset,
#     663     )
#     664 elif return_tensors == "tf":
#     665     return self._filter_masks_tf(
#     666         masks=masks,
#     667         iou_scores=iou_scores,
#    (...)
#     673         stability_score_offset=stability_score_offset,
#     674     )
#
# File ~/sar_env_2/lib/python3.9/site-packages/transformers/models/sam/image_processing_sam.py:752, in SamImageProcessor._filter_masks_pt(self, masks, iou_scores, original_size, cropped_box_image, pred_iou_thresh, stability_score_thresh, mask_threshold, stability_score_offset)
#     750 masks = _pad_masks(masks, cropped_box_image, original_height, original_width)
#     751 # conversion to rle is necessary to run non-maximum suppresion
# --> 752 masks = _mask_to_rle_pytorch(masks)
#     754 return masks, scores, converted_boxes
#
# File ~/sar_env_2/lib/python3.9/site-packages/transformers/models/sam/image_processing_sam.py:1180, in _mask_to_rle_pytorch(input_mask)
#    1178     btw_idxs = cur_idxs[1:] - cur_idxs[:-1]
#    1179     counts = [] if input_mask[i, 0] == 0 else [0]
# -> 1180     counts += [cur_idxs[0].item()] + btw_idxs.tolist() + [height * width - cur_idxs[-1]]
#    1181     out.append({"size": [height, width], "counts": counts})
#    1182 return out
#
# IndexError: index 0 is out of bounds for dimension 0 with size 0

# %%
_, ax = plt.subplots(1,3)

ax[0].imshow(raw_image[0])
ax[1].imshow(raw_image[1])
# ax[2].imshow(outputs['masks'][0])

for a in ax:
        a.set_xticks([])
        a.set_yticks([])

plt.show()

# %%
pil_image
# Out:
# <PIL.Image.Image image mode=L size=512x512>
